# %%
import pandas as pd
import pmdarima as pm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
con = pd.read_csv('time_series_covid19_confirmed_US.csv')
pro =pd.read_csv('time_series_covid19_deaths_US.csv')

# %%
US_confirmed = pd.melt(con, id_vars=['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
       'Country_Region', 'Lat', 'Long_', 'Combined_Key'])
US_confirmed['variable'] = pd.to_datetime(US_confirmed['variable'], infer_datetime_format=True)

# %%
US_deaths = pd.melt(pro, id_vars=['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
       'Country_Region', 'Lat', 'Long_', 'Combined_Key','Population'])
US_deaths['variable'] = pd.to_datetime(US_deaths['variable'], infer_datetime_format=True)

# %%
US_confirmed['variable'] = pd.to_datetime(US_confirmed['variable'], format='%y-%m-%d')
US_deaths['variable'] = pd.to_datetime(US_deaths['variable'], format='%y-%m-%d')

# %%
American_Samoa=US_deaths[US_deaths['Province_State']=='American Samoa']
Guam=US_deaths[US_deaths['Province_State']=='Guam']
Northern_Mariana_Islands=US_deaths[US_deaths['Province_State']=='Northern Mariana Islands']
Puerto_Rico=US_deaths[US_deaths['Province_State']=='Puerto Rico']
Virgin_Islands=US_deaths[US_deaths['Province_State']=='Virgin Islands']
Alabama=US_deaths[US_deaths['Province_State']=='Alabama']
Alaska=US_deaths[US_deaths['Province_State']=='Alaska']
Arizona=US_deaths[US_deaths['Province_State']=='Arizona']
Arkansas=US_deaths[US_deaths['Province_State']=='Arkansas']
California=US_deaths[US_deaths['Province_State']=='California']
Colorado=US_deaths[US_deaths['Province_State']=='Colorado']
Connecticut=US_deaths[US_deaths['Province_State']=='Connecticut']
Delaware=US_deaths[US_deaths['Province_State']=='Delaware']
District_of_Columbia=US_deaths[US_deaths['Province_State']=='District of Columbia']
Florida=US_deaths[US_deaths['Province_State']=='Florida']
Georgia=US_deaths[US_deaths['Province_State']=='Georgia']
Hawaii=US_deaths[US_deaths['Province_State']=='Hawaii']
Idaho=US_deaths[US_deaths['Province_State']=='Idaho']
Illinois=US_deaths[US_deaths['Province_State']=='Illinois']
Indiana=US_deaths[US_deaths['Province_State']=='Indiana']
Iowa=US_deaths[US_deaths['Province_State']=='Iowa']
Kansas=US_deaths[US_deaths['Province_State']=='Kansas']
Kentucky=US_deaths[US_deaths['Province_State']=='Kentucky']
Louisiana=US_deaths[US_deaths['Province_State']=='Louisiana']
Maine=US_deaths[US_deaths['Province_State']=='Maine']
Maryland=US_deaths[US_deaths['Province_State']=='Maryland']
Massachusetts=US_deaths[US_deaths['Province_State']=='Massachusetts']
Michigan=US_deaths[US_deaths['Province_State']=='Michigan']
Minnesota=US_deaths[US_deaths['Province_State']=='Minnesota']
Mississippi=US_deaths[US_deaths['Province_State']=='Mississippi']
Missouri=US_deaths[US_deaths['Province_State']=='Missouri']
Montana=US_deaths[US_deaths['Province_State']=='Montana']
Nebraska=US_deaths[US_deaths['Province_State']=='Nebraska']
Nevada=US_deaths[US_deaths['Province_State']=='Nevada']
New_Hampshire=US_deaths[US_deaths['Province_State']=='New Hampshire']
New_Jersey=US_deaths[US_deaths['Province_State']=='New Jersey']
New_Mexico=US_deaths[US_deaths['Province_State']=='New Mexico']
New_York=US_deaths[US_deaths['Province_State']=='New York']
North_Carolina=US_deaths[US_deaths['Province_State']=='North Carolina']
North_Dakota=US_deaths[US_deaths['Province_State']=='North Dakota']
Ohio=US_deaths[US_deaths['Province_State']=='Ohio']
Oklahoma=US_deaths[US_deaths['Province_State']=='Oklahoma']
Oregon=US_deaths[US_deaths['Province_State']=='Oregon']
Pennsylvania=US_deaths[US_deaths['Province_State']=='Pennsylvania']
Rhode_Island=US_deaths[US_deaths['Province_State']=='Rhode Island']
South_Carolina=US_deaths[US_deaths['Province_State']=='South Carolina']
South_Dakota=US_deaths[US_deaths['Province_State']=='South Dakota']
Tennessee=US_deaths[US_deaths['Province_State']=='Tennessee']
Texas=US_deaths[US_deaths['Province_State']=='Texas']
Utah=US_deaths[US_deaths['Province_State']=='Utah']
Vermont=US_deaths[US_deaths['Province_State']=='Vermont']
Virginia=US_deaths[US_deaths['Province_State']=='Virginia']
Washington=US_deaths[US_deaths['Province_State']=='Washington']
West_Virginia=US_deaths[US_deaths['Province_State']=='West Virginia']
Wisconsin=US_deaths[US_deaths['Province_State']=='Wisconsin']
Wyoming=US_deaths[US_deaths['Province_State']=='Wyoming']
Diamond_Princess=US_deaths[US_deaths['Province_State']=='Diamond Princess']
Grand_Princess=US_deaths[US_deaths['Province_State']=='Grand Princess']

# %%
US_deaths_states = [American_Samoa, Guam, Northern_Mariana_Islands,
       Puerto_Rico, Virgin_Islands, Alabama, Alaska, Arizona,
       Arkansas, California, Colorado, Connecticut, Delaware,
       District_of_Columbia, Florida, Georgia, Hawaii, Idaho,
       Illinois, Indiana, Iowa, Kansas, Kentucky, Louisiana,
       Maine, Maryland, Massachusetts, Michigan, Minnesota,
       Mississippi, Missouri, Montana, Nebraska, Nevada,
       New_Hampshire, New_Jersey, New_Mexico, New_York,
       North_Carolina, North_Dakota, Ohio, Oklahoma, Oregon,
       Pennsylvania, Rhode_Island, South_Carolina, South_Dakota,
       Tennessee, Texas, Utah, Vermont, Virginia, Washington,
       West_Virginia, Wisconsin, Wyoming, Diamond_Princess,
       Grand_Princess]

# %%
def setting_index(x):
    x.drop(['iso2', 'iso3', 'Admin2','Country_Region', 'Combined_Key'],inplace=True,axis=1)
    x.set_index(['variable'],inplace=True)
    x.resample('D').sum()
    return x

# %%
for i in US_deaths_states:
    setting_index(i)
# Out:
# /Users/jdanielkim123/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
Guam
# Out:
#             UID  code3  FIPS Province_State      Lat     Long_  Population  \
# variable
# 2020-01-22  316    316  66.0           Guam  13.4443  144.7937      164229
# 2020-01-23  316    316  66.0           Guam  13.4443  144.7937      164229
# 2020-01-24  316    316  66.0           Guam  13.4443  144.7937      164229
# 2020-01-25  316    316  66.0           Guam  13.4443  144.7937      164229
# 2020-01-26  316    316  66.0           Guam  13.4443  144.7937      164229
# ...         ...    ...   ...            ...      ...       ...         ...
# 2020-07-19  316    316  66.0           Guam  13.4443  144.7937      164229
# 2020-07-20  316    316  66.0           Guam  13.4443  144.7937      164229
# 2020-07-21  316    316  66.0           Guam  13.4443  144.7937      164229
# 2020-07-22  316    316  66.0           Guam  13.4443  144.7937      164229
# 2020-07-23  316    316  66.0           Guam  13.4443  144.7937      164229
#
#             value
# variable
# 2020-01-22      0
# ...

# %%
stuff = pd.concat([American_Samoa, Guam, Northern_Mariana_Islands,
       Puerto_Rico, Virgin_Islands, Alabama, Alaska, Arizona,
       Arkansas, California, Colorado, Connecticut, Delaware,
       District_of_Columbia, Florida, Georgia, Hawaii, Idaho,], axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-302fd7505a75> in <module>
#       2        Puerto_Rico, Virgin_Islands, Alabama, Alaska, Arizona,
#       3        Arkansas, California, Colorado, Connecticut, Delaware,
# ----> 4        District_of_Columbia, Florida, Georgia, Hawaii, Idaho,], axis =1)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     256     )
#     257
# --> 258     return op.get_result()
#     259
#     260
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     466                     obj_labels = mgr.axes[ax]
#     467                     if not new_labels.equals(obj_labels):
# ...

# %%
stuff
# Out:
#             UID  code3  FIPS  Province_State     Lat    Long_  Population  \
# variable
# 2020-01-22   16     16  60.0  American Samoa -14.271 -170.132       55641
# 2020-01-22   16     16  60.0  American Samoa -14.271 -170.132       55641
# 2020-01-22   16     16  60.0  American Samoa -14.271 -170.132       55641
# 2020-01-22   16     16  60.0  American Samoa -14.271 -170.132       55641
# 2020-01-22   16     16  60.0  American Samoa -14.271 -170.132       55641
# ...         ...    ...   ...             ...     ...      ...         ...
# 2020-07-23   16     16  60.0  American Samoa -14.271 -170.132       55641
# 2020-07-23   16     16  60.0  American Samoa -14.271 -170.132       55641
# 2020-07-23   16     16  60.0  American Samoa -14.271 -170.132       55641
# 2020-07-23   16     16  60.0  American Samoa -14.271 -170.132       55641
# 2020-07-23   16     16  60.0  American Samoa -14.271 -170.132       55641
#
# ...

# %%
deaths_concat = pd.concat([American_Samoa, Guam, Northern_Mariana_Islands,
       Puerto_Rico, Virgin_Islands, Alabama, Alaska, Arizona,
       Arkansas, California, Colorado, Connecticut, Delaware,
       District_of_Columbia, Florida, Georgia, Hawaii, Idaho,
       Illinois, Indiana, Iowa, Kansas, Kentucky, Louisiana,
       Maine, Maryland, Massachusetts, Michigan, Minnesota,
       Mississippi, Missouri, Montana, Nebraska, Nevada,
       New_Hampshire, New_Jersey, New_Mexico, New_York,
       North_Carolina, North_Dakota, Ohio, Oklahoma, Oregon,
       Pennsylvania, Rhode_Island, South_Carolina, South_Dakota,
       Tennessee, Texas, Utah, Vermont, Virginia, Washington,
       West_Virginia, Wisconsin, Wyoming, Diamond_Princess,
       Grand_Princess], axis=1)

# %%
deaths_concat

# %% [markdown]
# def setting_index(x):
#     return x.drop(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Country_Region', 'Lat', 'Long_', 'Combined_Key', 'Population'],inplace=True,axis=1)
#      #x.set_index('variable',inplace=True)

# %% [markdown]
# grouping=[American_Samoa,Guam,Northern_Mariana_Islands,Puerto_Rico,Virgin_Islands,Alabama,Alaska,Arizona,Arkansas,California,Colorado,Connecticut,Delaware,District_of_Columbia,Florida,Georgia,Hawaii,Idaho,Illinois,Indiana,Iowa,Kansas,Kentucky,Louisiana,Maine,Maryland,Massachusetts,Michigan,Minnesota,Mississippi,Missouri,Montana,Nebraska,Nevada,New_Hampshire,New_Jersey,New_Mexico,New_York,North_Carolina,North_Dakota,Ohio,Oklahoma,Oregon,Pennsylvania,Rhode_Island,South_Carolina,South_Dakota,Tennessee,Texas,Utah,Vermont,Virginia,Washington,West_Virginia,Wisconsin,Wyoming,Diamond_Princess,Grand_Princess]

# %% [markdown]
# New_York['Admin2'].unique()

# %% [markdown]
# NY_regions = ['Albany', 'Allegany', 'Bronx', 'Broome', 'Cattaraugus', 'Cayuga','Chautauqua', 'Chemung', 'Chenango', 'Clinton', 'Columbia','Cortland', 'Delaware', 'Dutchess', 'Erie', 'Essex', 'Franklin','Fulton', 'Genesee', 'Greene', 'Hamilton', 'Herkimer', 'Jefferson','Kings', 'Lewis', 'Livingston', 'Madison', 'Monroe', 'Montgomery','Nassau', 'New York', 'Niagara', 'Oneida', 'Onondaga', 'Ontario','Orange', 'Orleans', 'Oswego', 'Otsego', 'Putnam', 'Queens','Rensselaer', 'Richmond', 'Rockland', 'St. Lawrence', 'Saratoga','Schenectady', 'Schoharie', 'Schuyler', 'Seneca', 'Steuben','Suffolk', 'Sullivan', 'Tioga', 'Tompkins', 'Ulster', 'Warren','Washington', 'Wayne', 'Westchester', 'Wyoming', 'Yates','Out of NY', 'Unassigned']

# %% [markdown]
# for i in NY_regions:
#     listinging=[]
#     listinging.append('NY_{}'.format(i))

# %% [markdown]
# listinging

# %% [markdown]
# NY_Albany = New_York[New_York['Admin2']=='Albany']
# NY_Allegany = New_York[New_York['Admin2']=='Allegany']
# NY_Bronx = New_York[New_York['Admin2']=='Bronx']
# NY_Broome = New_York[New_York['Admin2']=='Broome']
# NY_Cattaraugus = New_York[New_York['Admin2']=='Cattaraugus']
# NY_Cayuga = New_York[New_York['Admin2']=='Cayuga']
# NY_Chautauqua = New_York[New_York['Admin2']=='Chautauqua']
# NY_Chemung = New_York[New_York['Admin2']=='Chemung']
# NY_Chenango = New_York[New_York['Admin2']=='Chenango']
# NY_Clinton = New_York[New_York['Admin2']=='Clinton']
# NY_Columbia = New_York[New_York['Admin2']=='Columbia']
# NY_Cortland = New_York[New_York['Admin2']=='Cortland']
# NY_Delaware = New_York[New_York['Admin2']=='Delaware']
# NY_Dutchess = New_York[New_York['Admin2']=='Dutchess']
# NY_Erie = New_York[New_York['Admin2']=='Erie']
# NY_Essex = New_York[New_York['Admin2']=='Essex']
# NY_Franklin = New_York[New_York['Admin2']=='Franklin']
# NY_Fulton = New_York[New_York['Admin2']=='Fulton']
# NY_Genesee = New_York[New_York['Admin2']=='Genesee']
# NY_Greene = New_York[New_York['Admin2']=='Greene']
# NY_Hamilton = New_York[New_York['Admin2']=='Hamilton']
# NY_Herkimer = New_York[New_York['Admin2']=='Herkimer']
# NY_Jefferson = New_York[New_York['Admin2']=='Jefferson']
# NY_Kings = New_York[New_York['Admin2']=='Kings']
# NY_Lewis = New_York[New_York['Admin2']=='Lewis']
# NY_Livingston = New_York[New_York['Admin2']=='Livingston']
# NY_Madison = New_York[New_York['Admin2']=='Madison']
# NY_Monroe = New_York[New_York['Admin2']=='Monroe']
# NY_Montgomery = New_York[New_York['Admin2']=='Montgomery']
# NY_Nassau = New_York[New_York['Admin2']=='Nassau']
# NY_New_York = New_York[New_York['Admin2']=='New York']
# NY_Niagara = New_York[New_York['Admin2']=='Niagara']
# NY_Oneida = New_York[New_York['Admin2']=='Oneida']
# NY_Onondaga = New_York[New_York['Admin2']=='Onondaga']
# NY_Ontario = New_York[New_York['Admin2']=='Ontario']
# NY_Orange = New_York[New_York['Admin2']=='Orange']
# NY_Orleans = New_York[New_York['Admin2']=='Orleans']
# NY_Oswego = New_York[New_York['Admin2']=='Oswego']
# NY_Otsego = New_York[New_York['Admin2']=='Otsego']
# NY_Putnam = New_York[New_York['Admin2']=='Putnam']
# NY_Queens = New_York[New_York['Admin2']=='Queens']
# NY_Rensselaer = New_York[New_York['Admin2']=='Rensselaer']
# NY_Richmond = New_York[New_York['Admin2']=='Richmond']
# NY_Rockland = New_York[New_York['Admin2']=='Rockland']
# NY_St_Lawrence = New_York[New_York['Admin2']=='St. Lawrence']
# NY_Saratoga = New_York[New_York['Admin2']=='Saratoga']
# NY_Schenectady = New_York[New_York['Admin2']=='Schenectady']
# NY_Schoharie = New_York[New_York['Admin2']=='Schoharie']
# NY_Schuyler = New_York[New_York['Admin2']=='Schuyler']
# NY_Seneca = New_York[New_York['Admin2']=='Seneca']
# NY_Steuben = New_York[New_York['Admin2']=='Steuben']
# NY_Suffolk = New_York[New_York['Admin2']=='Suffolk']
# NY_Sullivan = New_York[New_York['Admin2']=='Sullivan']
# NY_Tioga = New_York[New_York['Admin2']=='Tompkins']
# NY_Ulster = New_York[New_York['Admin2']=='Ulster']
# NY_Warren = New_York[New_York['Admin2']=='Warren']
# NY_Washington = New_York[New_York['Admin2']=='Washington']
# NY_Wayne = New_York[New_York['Admin2']=='Wayne']
# NY_Westchester = New_York[New_York['Admin2']=='Westchester']
# NY_Wyoming = New_York[New_York['Admin2']=='Wyoming']
# NY_Yates = New_York[New_York['Admin2']=='Yates']
# NY_Out_of_NY = New_York[New_York['Admin2']=='Out of NY']
# NY_Unassigned = New_York[New_York['Admin2']=='Unassigned']

# %% [markdown]
# NY_concat = pd.concat([Westchester,Newyork], axis=1)

# %% [markdown]
# NY_concat

# %% [markdown]
# sns.set()
# sns.set(style="whitegrid",palette="dark")
# fizer, line = plt.subplots(figsize=(20, 12))
# sns.lineplot(x="variable", y="value", data=Westchester, palette='GnBu_d')
# sns.lineplot(x="variable", y="value", data=Newyork, palette='GnBu_d')

# %% [markdown]
# US_confirmed[(US_confirmed['Province_State']== 'New York')& (US_confirmed['Admin2']== 'Westchester')]

# %% [markdown]
# NY = ['Albany, New York, US',
#  'Allegany, New York, US',
#  'Bronx, New York, US',
#  'Broome, New York, US',
#  'Cattaraugus, New York, US',
#  'Cayuga, New York, US',
#  'Chautauqua, New York, US',
#  'Chemung, New York, US',
#  'Chenango, New York, US',
#  'Clinton, New York, US',
#  'Columbia, New York, US',
#  'Cortland, New York, US',
#  'Delaware, New York, US',
#  'Dutchess, New York, US',
#  'Erie, New York, US',
#  'Essex, New York, US',
#  'Franklin, New York, US',
#  'Fulton, New York, US',
#  'Genesee, New York, US',
#  'Greene, New York, US',
#  'Hamilton, New York, US',
#  'Herkimer, New York, US',
#  'Jefferson, New York, US',
#  'Kings, New York, US',
#  'Lewis, New York, US',
#  'Livingston, New York, US',
#  'Madison, New York, US',
#  'Monroe, New York, US',
#  'Montgomery, New York, US',
#  'Nassau, New York, US',
#  'New York City, New York, US',
#  'Niagara, New York, US',
#  'Oneida, New York, US',
#  'Onondaga, New York, US',
#  'Ontario, New York, US',
#  'Orange, New York, US',
#  'Orleans, New York, US',
#  'Oswego, New York, US',
#  'Otsego, New York, US',
#  'Putnam, New York, US',
#  'Queens, New York, US',
#  'Rensselaer, New York, US',
#  'Richmond, New York, US',
#  'Rockland, New York, US',
#  'St. Lawrence, New York, US',
#  'Saratoga, New York, US',
#  'Schenectady, New York, US',
#  'Schoharie, New York, US',
#  'Schuyler, New York, US',
#  'Seneca, New York, US',
#  'Steuben, New York, US',
#  'Suffolk, New York, US',
#  'Sullivan, New York, US',
#  'Tioga, New York, US',
#  'Tompkins, New York, US',
#  'Ulster, New York, US',
#  'Warren, New York, US',
#  'Washington, New York, US',
#  'Wayne, New York, US',
#  'Westchester, New York, US',
#  'Wyoming, New York, US',
#  'Yates, New York, US',
#  'Out of NY, New York, US',
#  'Unassigned, New York, US']

# %% [markdown]
# US_confirmed
